# %% [markdown]
# <a href="https://colab.research.google.com/github/DyingTwice/MS/blob/main/MS_Lab_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lab 4: Enhancing the Bike Sharing System
#
# Welcome to **Lab 4** of the Modeling & Simulation course! In this laboratory session, we will build upon the foundations laid in the previous labs to enhance our bike-sharing system simulation. This lab introduces the concept of **time slot-specific probabilities**, allowing you to model varying bike usage patterns throughout the day. Additionally, you will implement bike maintenance and downtime, develop a rebalancing mechanism, track customer satisfaction, and undertake a **graded assignment** to design and implement a comprehensive simulation project.
#
# ---
#
# ## Table of Contents
#
# 1. [Recap of Previous Labs](#recap)
# 2. [Introduction to Time Slot-Specific Probabilities](#time-slots)
#    - [Understanding Time Slots](#understanding-time-slots)
# 3. [Implementing Time Slot-Specific Probabilities](#implementing-time-slots)
#    - [Defining Time Slots](#defining-time-slots)
# 4. [Graded Assignment Overview](#assignment)
#
# ---
#
# ## <a name="recap"></a>1. Recap of Previous Labs
#
# ### Lab 1: Python Introduction
# - Gained proficiency in Python programming.
# - Learned fundamental programming concepts such as variables, data types, control structures, functions, and basic I/O operations.
#
# ### Lab 2: Basic Bike Sharing System Modeling
# - Developed a simplified bike-sharing system using Python classes.
# - Modeled entities such as stations, bikes, and trips.
# - Implemented basic trip generation and analyzed system behavior over a short period.
#
# ### Lab 3: Introduction to SimPy
# - Introduced SimPy, a discrete-event simulation library in Python.
# - Reimplemented the bike-sharing system using SimPy constructs like environments, processes, and resources.
# - Explored extensions including variable trip durations, rebalancing strategies, and customer satisfaction tracking.
#
# ---
#
# ## <a name="time-slots"></a>2. Introduction to Time Slot-Specific Probabilities
#
# In real-world scenarios, bike usage varies throughout the day. To simulate this variability, we introduce **time slot-specific probabilities**. This enhancement allows the simulation to reflect different demand levels during various periods, such as morning rush hours and midday.
#
# ### <a name="understanding-time-slots"></a>Understanding Time Slots
#
# - **Time Slots:** Defined periods within a day where bike trip probabilities differ.
# - **Recurring Pattern:** Time slots repeat every simulated day, enabling multi-day simulations.
# - **Example Time Slots:**
#   - **Morning Start (0-120 minutes):** Initial hours with increasing demand.
#   - **Midday (120-720 minutes):** Peak hours with stable high demand.
#
# ### <a name="mapping-time"></a>Mapping Simulation Time to Real-Time
#
# To create realistic simulations, map simulation minutes to actual day times.
#
# - **Simulation Start Time:** 6:00 AM
# - **Morning Start:** 6:00 AM - 8:00 AM (0-120 minutes)
# - **Midday:** 8:00 AM - 6:00 PM (120-720 minutes)
# - **Simulation Duration:** 20 days (12 hours/day) → 14400 minutes
#
# ---
#
# ## <a name="implementing-time-slots"></a>3. Implementing Time Slot-Specific Probabilities
#
# ### <a name="defining-time-slots"></a>Defining Time Slots
#
# Define time slots with specific trip probability matrices within a single day. Use the modulo operation to map the current simulation time to the appropriate time slot.
#
# ```python
# # Define time slots for a single day
# time_slots = [
#     {
#         'name': 'morning_start',
#         'start': 0,       # 0 minutes into the day (6:00 AM)
#         'end': 120,       # 2 hours
#         'prob_matrix': {
#             ('A', 'B'): 0.4,
#             ('B', 'A'): 0.6,
#             ('A', 'C'): 0.2,
#             ('C', 'A'): 0.5,
#             ('B', 'C'): 0.3,
#             ('C', 'B'): 0.4,
#             ('A', 'D'): 0.3,
#             ('D', 'A'): 0.2,
#         }
#     },
#     {
#         'name': 'midday',
#         'start': 120,      # 2 hours into the day (8:00 AM)
#         'end': 720,        # 12 hours total (6:00 PM)
#         'prob_matrix': {
#             ('A', 'B'): 0.2,
#             ('B', 'A'): 0.3,
#             ('A', 'C'): 0.1,
#             ('C', 'A'): 0.2,
#             ('B', 'C'): 0.25,
#             ('C', 'B'): 0.35,
#             ('A', 'D'): 0.15,
#             ('D', 'A'): 0.25,
#         }
#     }
#     # Add more time slots if needed
# ]
#
# # Define default probability matrix if no slot matches
# default_prob_matrix = {
#     ('A', 'B'): 0.05,
#     ('B', 'A'): 0.05,
#     ('A', 'C'): 0.05,
#     ('C', 'A'): 0.05,
#     ('B', 'C'): 0.05,
#     ('C', 'B'): 0.05,
#     ('A', 'D'): 0.05,
#     ('D', 'A'): 0.05,
# }

# %%
# Start from the code you've implemented in lab 3, add time-slot specific probabilities below

# %% [markdown]
# ## <a name="assignment"></a>Graded Assignment Overview
#
# Design and implement an enhanced bike-sharing system simulation using **SimPy**, incorporating advanced features to model a realistic and complex environment. Your simulation should build upon the concepts learned in previous labs and include the following components:
#
# ---
#
# Your simulation must include the following elements:
#
# ### 1. Multiple Stations:
#
# - **Minimum of Four stations** with varying capacities and initial bike counts.
# - Each station should have a unique name, capacity, and initial number of bikes.
#
# ### 2. Time-Dependent Trip Probabilities:
#
# - Implement trip probabilities that change based on different time slots (e.g., morning start, midday).
# - Define at least **two distinct time slots** with different probability matrices.
# - Ensure that time slots are **recurring daily** over the simulation period.
#
# ### 3. Bike Maintenance and Downtime:
#
# - Model bike failures with a specified failure probability during trips.
# - Implement a repair process that handles broken bikes, making them unavailable until repaired. The implementation details are up to your imagination.
# - Track and report the number of bikes under maintenance.
#
# ### 4. Rebalancing Mechanism:
#
# - Develop a rebalancing strategy to redistribute bikes between stations based on current demand and bike levels.
# - Rebalancing should occur at regular intervals (e.g., every 20 minutes) and follow defined criteria.
#
# ### 5. Customer Satisfaction Tracking:
#
# - Track the number of **unhappy customers** who cannot rent a bike due to unavailability.
# - Track the number of **unhappy customers** who cannot return a bike due to full stations.
#
# ### 6. Data Collection and Visualization:
#
# - Collect data on **bike levels** at each station over time.
# - Collect data on **broken bikes** and maintenance activities.
# - Collect data on **customer satisfaction** metrics.
# - Generate plots to visualize:
#   - **Bike levels** at each station over time.
#   - **Number of bikes under maintenance**.
#   - **Customer satisfaction metrics** (e.g., unhappy customers over time).
#
# ### 7. Simulation:
#
# - Allow the simulation to run for a configurable duration (e.g., **20 days**).
# - Parameters such as the number of stations, capacities, initial bikes, trip probabilities, maintenance rates, rebalancing intervals, and simulation duration should be easily adjustable.
# - Simulate and observe the system with various parameters.
#
# ---
#
# #### (Optional) Money Earning Mechanism:
#
# - Introduce a system where the bike-sharing service earns **money based on bike rentals** (e.g., per hour rented).
# - Track and report **total earnings** over the simulation period.
#
# ## What to Look For in Your Simulations
#
# The primary objective of this lab is to enable you to create a realistic and dynamic simulation of a bike-sharing system that accounts for daily usage patterns, system maintenance, and operational strategies. Things to look for:
#
# * Bike Availability: Assess how well the rebalancing mechanism maintains adequate bike levels across stations.
# * Maintenance Impact: Evaluate the effect of bike failures on system performance and customer satisfaction.
# * Customer Satisfaction: Analyze the number of unhappy customers and identify patterns or causes.
#
# Write down a couple of observations from your simulations to accompany the presentation of your system.
#
# ## Grading
#
# You will present your work in the upcoming laboratory, showing your system implementation and 1-3 simulations that you ran. The simulations should be accompanied by visual plots and you are encouraged to present any interesting observations about your system (e.g. with environment setup X the customer dissatisfaction drops significantly when increasing the rebalancing frequency to value y).
#
# The project grade will be determined by the grade of completion of your system (how much of the project task has been implemented), as well as your understanding of it. The latter will be assessed through some basic questions about your model/system/simulations.
#
# *Note: Where not strongly specified, you are free to design a subsystem/idea however you find best fit, e.g. points 2, 3 and 4 can have many different subsystem designs. There is no one correct way to do it.

# %%
# !pip install simpy
# Out:
# Requirement already satisfied: simpy in /usr/local/lib/python3.10/dist-packages (4.1.1)

# %%
import simpy
import random
import matplotlib.pyplot as plt

# The Environment in SimPy manages the simulation time and handles event scheduling. It acts as the central controller of the simulation.
env = simpy.Environment()

# Processes are functions that yield events. They simulate the behavior of active components in the system, like customers, machines, or in our case, bikes and trips.
# Example of a simple process
def simple_process(env):
    while True:
        print(f"Time {env.now}: Process is running")
        yield env.timeout(1)  # Wait for 1 time unit


# To start a process in SimPy, you add it to the environment:
env.process(simple_process(env))
# Out:
# <Process(simple_process) object at 0x7c34cb606800>

# %%
# Defining the Station Class
import simpy
import random

class Station:
    def __init__(self, env, name, capacity, init_bikes):
        self.env = env
        self.name = name
        self.capacity = capacity
        self.bikes = simpy.Container(env, init=init_bikes, capacity=capacity)

    def available_space(self):
        """Returns the number of available spaces at the station."""
        return self.capacity - self.bikes.level

    def return_bike(self):
        """Returns a repaired bike to the station."""
        if self.bikes.level < self.capacity:
            yield self.bikes.put(1)  # Put the bike back into the station's container
            print(f"Time {self.env.now}: Repaired bike returned to {self.name}. Bikes at station: {self.bikes.level}")
        else:
            print(f"Time {self.env.now}: {self.name} is full. Cannot return repaired bike.")

# %%
from os import stat
# Create stations
UPT_station = Station(env, "UPT", capacity=10, init_bikes=5)
UVT_station = Station(env, "UVT", capacity=15, init_bikes=8)
CENTER_station= Station(env, "CENTER", capacity=12, init_bikes=6)
PARK_station = Station(env, "PARK", capacity=8, init_bikes=0)

stations = [UPT_station, UVT_station, CENTER_station, PARK_station]

# %%
class Maintenance:
    def __init__(self):
        self.repaired_bikes = []
        self.rebalance_interval = 60  # Rebalance every 60 minutes
        self.unhappy_customers_rent = 0  # Count of unhappy customers who cannot rent bikes
        self.unhappy_customers_full_station = 0  # Count of unhappy customers who cannot return bikes

    def repair_bike(self, bike):
        """Simulate bike repair and add it to the repaired bikes list."""
        self.repaired_bikes.append(bike)

    def return_repaired_bikes(self):
        """Return repaired bikes to stations with available space."""
        for bike in self.repaired_bikes:
            for station in stations:
                if station.available_space() > 0:
                    env.process(station.return_bike())  # Return bike to the station
                    break  # Move on to the next bike after successfully returning
            else:
                print(f"Time {env.now}: No available space for bike {bike}.")  # No space found for this bike

        # Clear the repaired bikes list after returning
        self.repaired_bikes.clear()

    def rebalance(self):
        """Rebalance bikes among stations every defined interval."""
        while True:
            yield env.timeout(self.rebalance_interval)
            print(f"Time {env.now}: Rebalancing bikes...")

            # Calculate average bikes across all stations
            total_bikes = sum(station.bikes.level for station in stations)
            average_bikes = total_bikes // len(stations)  # Use integer division

            for station in stations:
                if station.bikes.level > average_bikes:  # This station has excess bikes
                    excess_bikes = station.bikes.level - average_bikes
                    print(f"{station.name} has {excess_bikes} excess bikes.")

                    # Move excess bikes to stations that need them
                    for other_station in stations:
                        if other_station != station and other_station.available_space() > 0:
                            bikes_to_move = min(excess_bikes, other_station.available_space())
                            station.bikes.get(bikes_to_move)  # Remove bikes from the current station
                            other_station.bikes.put(bikes_to_move)  # Add bikes to the other station
                            print(f"Moved {bikes_to_move} bikes from {station.name} to {other_station.name}.")
                            excess_bikes -= bikes_to_move
                            if excess_bikes <= 0:
                                break

# Initialize maintenance
maintenance = Maintenance()

bike_failure_probability = 0.50  # 50% chance of a bike breaking down during a trip

# %%
# Define time slots for a single day
# Define trip probabilities
time_slots = [
    {
        'name': 'morning_start',
        'start': 0,       # 0 minutes into the day (6:00 AM)
        'end': 120,       # 2 hours
        'prob_matrix': {
            ('UPT', 'UVT'): 0.4,
            ('UVT', 'UPT'): 0.6,
            ('UPT', 'CENTER'): 0.2,
            ('CENTER', 'UPT'): 0.5,
            ('UVT', 'CENTER'): 0.3,
            ('CENTER', 'UVT'): 0.4,
            ('UPT', 'PARK'): 0.3,
            ('PARK', 'UPT'): 0.2,
        }
    },
    {
        'name': 'midday',
        'start': 120,      # 2 hours into the day (8:00 AM) = 120 minutes
        'end': 720,        # 12 hours total (6:00 PM)
        'prob_matrix': {
            ('UPT', 'UVT'): 0.2,
            ('UVT', 'UPT'): 0.3,
            ('UPT', 'CENTER'): 0.1,
            ('CENTER', 'UPT'): 0.2,
            ('UVT', 'CENTER'): 0.25,
            ('CENTER', 'UVT'): 0.35,
            ('UPT', 'PARK'): 0.15,
            ('PARK', 'UPT'): 0.25,
        }
    }
]

# Define a default probability matrix for times that don't match any time slot
default_prob_matrix = {
    ('UPT', 'UVT'): 0.05,
    ('UVT', 'UPT'): 0.05,
    ('UPT', 'CENTER'): 0.05,
    ('CENTER', 'UPT'): 0.05,
    ('UVT', 'CENTER'): 0.05,
    ('CENTER', 'UVT'): 0.05,
    ('UPT', 'PARK'): 0.05,
    ('PARK', 'UPT'): 0.05,
}

# %%
# Function to get the probability matrix based on current time
def get_prob_matrix(current_time):
    for slot in time_slots:
        if slot['start'] <= current_time < slot['end']:
            return slot['prob_matrix']
    return default_prob_matrix

# Function to generate a trip
def generate_trip(env, stations, maintenance):
    while True:
        current_time = env.now % 1440
        prob_matrix = get_prob_matrix(current_time)

        trips = list(prob_matrix.keys())
        probabilities = list(prob_matrix.values())
        trip = random.choices(trips, probabilities)[0]

        origin, destination = trip
        print(f"Time {env.now}: Trip from {origin} to {destination}")

        # Check if there are bikes available to rent
        if stations[next(i for i, station in enumerate(stations) if station.name == origin)].available_space() == 0:
            print(f"Time {env.now}: Customer unhappy. No bikes available at {origin}.")
            maintenance.unhappy_customers_rent += 1  # Increment unhappy customer counter

        if random.random() < bike_failure_probability:
            print(f"Time {env.now}: Bike broke down on the trip from {origin} to {destination}")
            maintenance.repair_bike("Bike")  # Repair the broken bike

        trip_duration = random.randint(10, 20)
        yield env.timeout(trip_duration)

# Start the trip generation process
env.process(generate_trip(env, stations, maintenance))

# Start the rebalancing process
env.process(maintenance.rebalance())

# Run the simulation for 24 hours (1440 minutes)
env.run(until=1440)

# Print out customer satisfaction statistics
print(f"\nUnhappy customers who could not rent a bike: {maintenance.unhappy_customers_rent}")
print(f"Unhappy customers who could not return a bike due to full stations: {maintenance.unhappy_customers_full_station}")
# Out:
# Time 0: Process is running
# Time 0: Trip from CENTER to UPT
# Time 1: Process is running
# Time 2: Process is running
# Time 3: Process is running
# Time 4: Process is running
# Time 5: Process is running
# Time 6: Process is running
# Time 7: Process is running
# Time 8: Process is running
# Time 9: Process is running
# Time 10: Process is running
# Time 11: Process is running
# Time 12: Trip from UVT to UPT
# Time 12: Process is running
# Time 13: Process is running
# Time 14: Process is running
# Time 15: Process is running
# Time 16: Process is running
# Time 17: Process is running
# Time 18: Process is running
# Time 19: Process is running
# Time 20: Process is running
# Time 21: Process is running
# Time 22: Process is running
# Time 23: Process is running
# Time 24: Process is running
# Time 25: Process is running
# Time 26: Process is running
# Time 27: Process is running
# Time 28: Process is running
# Time 29: Trip from UPT to UVT
# Time 29: Process is running
# Time 30: Process is running
# Time 31: Process is running
# Time 32: Process is running
# Time 33: Process is running
# Time 34: Process is running
# Time 35: Process is running
# Time 36: Process is running
# Time 37: Process is running
# Time 38: Process is running
# Time 39: Process is running
# Time 40: Trip from UVT to UPT
# Time 40: Bike broke down on the trip from UVT to UPT
# Time 40: Process is running
# Time 41: Process is running
# Time 42: Process is running
# Time 43: Process is running
# Time 44: Process is running
# Time 45: Process is running
# Time 46: Process is running
# Time 47: Process is running
# Time 48: Process is running
# Time 49: Process is running
# Time 50: Process is running
# Time 51: Process is running
# Time 52: Process is running
# Time 53: Process is running
# Time 54: Process is running
# Time 55: Trip from UVT to UPT
# Time 55: Process is running
# Time 56: Process is running
# Time 57: Process is running
# Time 58: Process is running
# Time 59: Process is running
# Time 60: Rebalancing bikes...
# UPT has 1 excess bikes.
# Moved 1 bikes from UPT to UVT.
# UVT has 5 excess bikes.
# Moved 5 bikes from UVT to UPT.
# CENTER has 2 excess bikes.
# Moved 1 bikes from CENTER to UPT.
# Moved 1 bikes from CENTER to UVT.
# Time 60: Process is running
# Time 61: Process is running
# Time 62: Process is running
# Time 63: Process is running
# Time 64: Process is running
# Time 65: Process is running
# Time 66: Process is running
# Time 67: Process is running
# Time 68: Process is running
# Time 69: Process is running
# Time 70: Process is running
# Time 71: Process is running
# Time 72: Process is running
# Time 73: Process is running
# Time 74: Process is running
# Time 75: Trip from UPT to UVT
# Time 75: Customer unhappy. No bikes available at UPT.
# Time 75: Process is running
# Time 76: Process is running
# Time 77: Process is running
# Time 78: Process is running
# Time 79: Process is running
# Time 80: Process is running
# Time 81: Process is running
# Time 82: Process is running
# Time 83: Process is running
# Time 84: Process is running
# Time 85: Process is running
# Time 86: Process is running
# Time 87: Trip from CENTER to UPT
# Time 87: Process is running
# Time 88: Process is running
# Time 89: Process is running
# Time 90: Process is running
# Time 91: Process is running
# Time 92: Process is running
# Time 93: Process is running
# Time 94: Process is running
# Time 95: Process is running
# Time 96: Process is running
# Time 97: Process is running
# Time 98: Trip from UVT to UPT
# Time 98: Process is running
# Time 99: Process is running
# Time 100: Process is running
# Time 101: Process is running
# Time 102: Process is running
# Time 103: Process is running
# Time 104: Process is running
# Time 105: Process is running
# Time 106: Process is running
# Time 107: Process is running
# Time 108: Process is running
# Time 109: Process is running
# Time 110: Process is running
# Time 111: Process is running
# Time 112: Process is running
# Time 113: Process is running
# Time 114: Process is running
# Time 115: Process is running
# Time 116: Trip from CENTER to UVT
# Time 116: Process is running
# Time 117: Process is running
# Time 118: Process is running
# Time 119: Process is running
# Time 120: Rebalancing bikes...
# UPT has 6 excess bikes.
# Moved 6 bikes from UPT to UVT.
# UVT has 7 excess bikes.
# Moved 6 bikes from UVT to UPT.
# Moved 1 bikes from UVT to CENTER.
# CENTER has 1 excess bikes.
# Moved 1 bikes from CENTER to UVT.
# Time 120: Process is running
# Time 121: Process is running
# Time 122: Process is running
# Time 123: Process is running
# Time 124: Process is running
# Time 125: Process is running
# Time 126: Process is running
# Time 127: Process is running
# Time 128: Process is running
# Time 129: Process is running
# Time 130: Process is running
# Time 131: Process is running
# Time 132: Process is running
# Time 133: Process is running
# Time 134: Process is running
# Time 135: Process is running
# Time 136: Trip from UVT to UPT
# Time 136: Process is running
# Time 137: Process is running
# Time 138: Process is running
# Time 139: Process is running
# Time 140: Process is running
# Time 141: Process is running
# Time 142: Process is running
# Time 143: Process is running
# Time 144: Process is running
# Time 145: Process is running
# Time 146: Trip from CENTER to UVT
# Time 146: Bike broke down on the trip from CENTER to UVT
# Time 146: Process is running
# Time 147: Process is running
# Time 148: Process is running
# Time 149: Process is running
# Time 150: Process is running
# Time 151: Process is running
# Time 152: Process is running
# Time 153: Process is running
# Time 154: Process is running
# Time 155: Process is running
# Time 156: Process is running
# Time 157: Process is running
# Time 158: Process is running
# Time 159: Process is running
# Time 160: Process is running
# Time 161: Process is running
# Time 162: Process is running
# Time 163: Process is running
# Time 164: Process is running
# Time 165: Process is running
# Time 166: Trip from CENTER to UPT
# Time 166: Process is running
# Time 167: Process is running
# Time 168: Process is running
# Time 169: Process is running
# Time 170: Process is running
# Time 171: Process is running
# Time 172: Process is running
# Time 173: Process is running
# Time 174: Process is running
# Time 175: Process is running
# Time 176: Process is running
# Time 177: Process is running
# Time 178: Process is running
# Time 179: Process is running
# Time 180: Rebalancing bikes...
# UPT has 6 excess bikes.
# Moved 6 bikes from UPT to UVT.
# UVT has 7 excess bikes.
# Moved 6 bikes from UVT to UPT.
# Moved 1 bikes from UVT to CENTER.
# CENTER has 1 excess bikes.
# Moved 1 bikes from CENTER to UVT.
# Time 180: Process is running
# Time 181: Process is running
# Time 182: Process is running
# Time 183: Process is running
# Time 184: Process is running
# Time 185: Trip from UVT to CENTER
# Time 185: Process is running
# Time 186: Process is running
# Time 187: Process is running
# Time 188: Process is running
# Time 189: Process is running
# Time 190: Process is running
# Time 191: Process is running
# Time 192: Process is running
# Time 193: Process is running
# Time 194: Process is running
# Time 195: Process is running
# Time 196: Process is running
# Time 197: Process is running
# Time 198: Trip from UVT to CENTER
# Time 198: Bike broke down on the trip from UVT to CENTER
# Time 198: Process is running
# Time 199: Process is running
# Time 200: Process is running
# Time 201: Process is running
# Time 202: Process is running
# Time 203: Process is running
# Time 204: Process is running
# Time 205: Process is running
# Time 206: Process is running
# Time 207: Process is running
# Time 208: Process is running
# Time 209: Process is running
# Time 210: Process is running
# Time 211: Process is running
# Time 212: Process is running
# Time 213: Process is running
# Time 214: Process is running
# Time 215: Process is running
# Time 216: Trip from UVT to CENTER
# Time 216: Process is running
# Time 217: Process is running
# Time 218: Process is running
# Time 219: Process is running
# Time 220: Process is running
# Time 221: Process is running
# Time 222: Process is running
# Time 223: Process is running
# Time 224: Process is running
# Time 225: Process is running
# Time 226: Process is running
# Time 227: Process is running
# Time 228: Process is running
# Time 229: Process is running
# Time 230: Process is running
# Time 231: Process is running
# Time 232: Process is running
# Time 233: Process is running
# Time 234: Trip from CENTER to UVT
# Time 234: Process is running
# Time 235: Process is running
# Time 236: Process is running
# Time 237: Process is running
# Time 238: Process is running
# Time 239: Process is running
# Time 240: Rebalancing bikes...
# UPT has 6 excess bikes.
# Moved 6 bikes from UPT to UVT.
# UVT has 7 excess bikes.
# Moved 6 bikes from UVT to UPT.
# Moved 1 bikes from UVT to CENTER.
# CENTER has 1 excess bikes.
# Moved 1 bikes from CENTER to UVT.
# Time 240: Process is running
# Time 241: Process is running
# Time 242: Process is running
# Time 243: Process is running
# Time 244: Process is running
# Time 245: Process is running
# Time 246: Process is running
# Time 247: Trip from UPT to PARK
# Time 247: Customer unhappy. No bikes available at UPT.
# Time 247: Bike broke down on the trip from UPT to PARK
# Time 247: Process is running
# Time 248: Process is running
# Time 249: Process is running
# Time 250: Process is running
# Time 251: Process is running
# Time 252: Process is running
# Time 253: Process is running
# Time 254: Process is running
# Time 255: Process is running
# Time 256: Process is running
# Time 257: Trip from UVT to UPT
# Time 257: Bike broke down on the trip from UVT to UPT
# Time 257: Process is running
# Time 258: Process is running
# Time 259: Process is running
# Time 260: Process is running
# Time 261: Process is running
# Time 262: Process is running
# Time 263: Process is running
# Time 264: Process is running
# Time 265: Process is running
# Time 266: Process is running
# Time 267: Process is running
# Time 268: Process is running
# Time 269: Process is running
# Time 270: Process is running
# Time 271: Process is running
# Time 272: Process is running
# Time 273: Process is running
# Time 274: Trip from CENTER to UVT
# Time 274: Bike broke down on the trip from CENTER to UVT
# Time 274: Process is running
# Time 275: Process is running
# Time 276: Process is running
# Time 277: Process is running
# Time 278: Process is running
# Time 279: Process is running
# Time 280: Process is running
# Time 281: Process is running
# Time 282: Process is running
# Time 283: Process is running
# Time 284: Process is running
# Time 285: Trip from UPT to CENTER
# Time 285: Customer unhappy. No bikes available at UPT.
# Time 285: Process is running
# Time 286: Process is running
# Time 287: Process is running
# Time 288: Process is running
# Time 289: Process is running
# Time 290: Process is running
# Time 291: Process is running
# Time 292: Process is running
# Time 293: Process is running
# Time 294: Process is running
# Time 295: Process is running
# Time 296: Process is running
# Time 297: Trip from PARK to UPT
# Time 297: Bike broke down on the trip from PARK to UPT
# Time 297: Process is running
# Time 298: Process is running
# Time 299: Process is running
# Time 300: Rebalancing bikes...
# UPT has 6 excess bikes.
# Moved 6 bikes from UPT to UVT.
# UVT has 7 excess bikes.
# Moved 6 bikes from UVT to UPT.
# Moved 1 bikes from UVT to CENTER.
# CENTER has 1 excess bikes.
# Moved 1 bikes from CENTER to UVT.
# Time 300: Process is running
# Time 301: Process is running
# Time 302: Process is running
# Time 303: Process is running
# Time 304: Process is running
# Time 305: Process is running
# Time 306: Process is running
# Time 307: Process is running
# Time 308: Process is running
# Time 309: Process is running
# Time 310: Trip from CENTER to UVT
# Time 310: Process is running
# Time 311: Process is running
# Time 312: Process is running
# Time 313: Process is running
# Time 314: Process is running
# Time 315: Process is running
# Time 316: Process is running
# Time 317: Process is running
# Time 318: Process is running
# Time 319: Process is running
# Time 320: Trip from UVT to CENTER
# Time 320: Bike broke down on the trip from UVT to CENTER
# Time 320: Process is running
# Time 321: Process is running
# Time 322: Process is running
# Time 323: Process is running
# Time 324: Process is running
# Time 325: Process is running
# Time 326: Process is running
# Time 327: Process is running
# Time 328: Process is running
# Time 329: Process is running
# Time 330: Process is running
# Time 331: Process is running
# Time 332: Trip from UVT to CENTER
# Time 332: Process is running
# Time 333: Process is running
# Time 334: Process is running
# Time 335: Process is running
# Time 336: Process is running
# Time 337: Process is running
# Time 338: Process is running
# Time 339: Process is running
# Time 340: Process is running
# Time 341: Process is running
# Time 342: Process is running
# Time 343: Process is running
# Time 344: Process is running
# Time 345: Process is running
# Time 346: Process is running
# Time 347: Process is running
# Time 348: Process is running
# Time 349: Process is running
# Time 350: Trip from PARK to UPT
# Time 350: Bike broke down on the trip from PARK to UPT
# Time 350: Process is running
# Time 351: Process is running
# Time 352: Process is running
# Time 353: Process is running
# Time 354: Process is running
# Time 355: Process is running
# Time 356: Process is running
# Time 357: Process is running
# Time 358: Process is running
# Time 359: Process is running
# Time 360: Rebalancing bikes...
# UPT has 6 excess bikes.
# Moved 6 bikes from UPT to UVT.
# UVT has 7 excess bikes.
# Moved 6 bikes from UVT to UPT.
# Moved 1 bikes from UVT to CENTER.
# CENTER has 1 excess bikes.
# Moved 1 bikes from CENTER to UVT.
# Time 360: Process is running
# Time 361: Process is running
# Time 362: Process is running
# Time 363: Process is running
# Time 364: Process is running
# Time 365: Process is running
# Time 366: Trip from UPT to UVT
# Time 366: Customer unhappy. No bikes available at UPT.
# Time 366: Bike broke down on the trip from UPT to UVT
# Time 366: Process is running
# Time 367: Process is running
# Time 368: Process is running
# Time 369: Process is running
# Time 370: Process is running
# Time 371: Process is running
# Time 372: Process is running
# Time 373: Process is running
# Time 374: Process is running
# Time 375: Process is running
# Time 376: Process is running
# Time 377: Process is running
# Time 378: Process is running
# Time 379: Process is running
# Time 380: Process is running
# Time 381: Process is running
# Time 382: Process is running
# Time 383: Trip from UVT to UPT
# Time 383: Bike broke down on the trip from UVT to UPT
# Time 383: Process is running
# Time 384: Process is running
# Time 385: Process is running
# Time 386: Process is running
# Time 387: Process is running
# Time 388: Process is running
# Time 389: Process is running
# Time 390: Process is running
# Time 391: Process is running
# Time 392: Process is running
# Time 393: Process is running
# Time 394: Process is running
# Time 395: Process is running
# Time 396: Process is running
# Time 397: Process is running
# Time 398: Process is running
# Time 399: Process is running
# Time 400: Process is running
# Time 401: Trip from CENTER to UPT
# Time 401: Process is running
# Time 402: Process is running
# Time 403: Process is running
# Time 404: Process is running
# Time 405: Process is running
# Time 406: Process is running
# Time 407: Process is running
# Time 408: Process is running
# Time 409: Process is running
# Time 410: Process is running
# Time 411: Process is running
# Time 412: Process is running
# Time 413: Process is running
# Time 414: Trip from UVT to CENTER
# Time 414: Bike broke down on the trip from UVT to CENTER
# Time 414: Process is running
# Time 415: Process is running
# Time 416: Process is running
# Time 417: Process is running
# Time 418: Process is running
# Time 419: Process is running
# Time 420: Rebalancing bikes...
# UPT has 6 excess bikes.
# Moved 6 bikes from UPT to UVT.
# UVT has 7 excess bikes.
# Moved 6 bikes from UVT to UPT.
# Moved 1 bikes from UVT to CENTER.
# CENTER has 1 excess bikes.
# Moved 1 bikes from CENTER to UVT.
# Time 420: Process is running
# Time 421: Process is running
# Time 422: Process is running
# Time 423: Process is running
# Time 424: Process is running
# Time 425: Process is running
# Time 426: Process is running
# Time 427: Trip from UPT to CENTER
# Time 427: Customer unhappy. No bikes available at UPT.
# Time 427: Process is running
# Time 428: Process is running
# Time 429: Process is running
# Time 430: Process is running
# Time 431: Process is running
# Time 432: Process is running
# Time 433: Process is running
# Time 434: Process is running
# Time 435: Process is running
# Time 436: Process is running
# Time 437: Process is running
# Time 438: Process is running
# Time 439: Process is running
# Time 440: Trip from UVT to UPT
# Time 440: Process is running
# Time 441: Process is running
# Time 442: Process is running
# Time 443: Process is running
# Time 444: Process is running
# Time 445: Process is running
# Time 446: Process is running
# Time 447: Process is running
# Time 448: Process is running
# Time 449: Process is running
# Time 450: Process is running
# Time 451: Process is running
# Time 452: Process is running
# Time 453: Process is running
# Time 454: Process is running
# Time 455: Process is running
# Time 456: Process is running
# Time 457: Process is running
# Time 458: Process is running
# Time 459: Process is running
# Time 460: Trip from UPT to CENTER
# Time 460: Customer unhappy. No bikes available at UPT.
# Time 460: Process is running
# Time 461: Process is running
# Time 462: Process is running
# Time 463: Process is running
# Time 464: Process is running
# Time 465: Process is running
# Time 466: Process is running
# Time 467: Process is running
# Time 468: Process is running
# Time 469: Process is running
# Time 470: Process is running
# Time 471: Process is running
# Time 472: Trip from CENTER to UVT
# Time 472: Bike broke down on the trip from CENTER to UVT
# Time 472: Process is running
# Time 473: Process is running
# Time 474: Process is running
# Time 475: Process is running
# Time 476: Process is running
# Time 477: Process is running
# Time 478: Process is running
# Time 479: Process is running
# Time 480: Rebalancing bikes...
# UPT has 6 excess bikes.
# Moved 6 bikes from UPT to UVT.
# UVT has 7 excess bikes.
# Moved 6 bikes from UVT to UPT.
# Moved 1 bikes from UVT to CENTER.
# CENTER has 1 excess bikes.
# Moved 1 bikes from CENTER to UVT.
# Time 480: Process is running
# Time 481: Process is running
# Time 482: Process is running
# Time 483: Process is running
# Time 484: Process is running
# Time 485: Process is running
# Time 486: Process is running
# Time 487: Process is running
# Time 488: Trip from PARK to UPT
# Time 488: Process is running
# Time 489: Process is running
# Time 490: Process is running
# Time 491: Process is running
# Time 492: Process is running
# Time 493: Process is running
# Time 494: Process is running
# Time 495: Process is running
# Time 496: Process is running
# Time 497: Process is running
# Time 498: Process is running
# Time 499: Process is running
# Time 500: Process is running
# Time 501: Process is running
# Time 502: Process is running
# Time 503: Process is running
# Time 504: Process is running
# Time 505: Trip from UPT to CENTER
# Time 505: Customer unhappy. No bikes available at UPT.
# Time 505: Process is running
# Time 506: Process is running
# Time 507: Process is running
# Time 508: Process is running
# Time 509: Process is running
# Time 510: Process is running
# Time 511: Process is running
# Time 512: Process is running
# Time 513: Process is running
# Time 514: Process is running
# Time 515: Trip from UPT to UVT
# Time 515: Customer unhappy. No bikes available at UPT.
# Time 515: Process is running
# Time 516: Process is running
# Time 517: Process is running
# Time 518: Process is running
# Time 519: Process is running
# Time 520: Process is running
# Time 521: Process is running
# Time 522: Process is running
# Time 523: Process is running
# Time 524: Process is running
# Time 525: Process is running
# Time 526: Process is running
# Time 527: Process is running
# Time 528: Process is running
# Time 529: Process is running
# Time 530: Process is running
# Time 531: Process is running
# Time 532: Process is running
# Time 533: Trip from UPT to UVT
# Time 533: Customer unhappy. No bikes available at UPT.
# Time 533: Process is running
# Time 534: Process is running
# Time 535: Process is running
# Time 536: Process is running
# Time 537: Process is running
# Time 538: Process is running
# Time 539: Process is running
# Time 540: Rebalancing bikes...
# UPT has 6 excess bikes.
# Moved 6 bikes from UPT to UVT.
# UVT has 7 excess bikes.
# Moved 6 bikes from UVT to UPT.
# Moved 1 bikes from UVT to CENTER.
# CENTER has 1 excess bikes.
# Moved 1 bikes from CENTER to UVT.
# Time 540: Process is running
# Time 541: Process is running
# Time 542: Process is running
# Time 543: Process is running
# Time 544: Process is running
# Time 545: Process is running
# Time 546: Process is running
# Time 547: Process is running
# Time 548: Process is running
# Time 549: Process is running
# Time 550: Process is running
# Time 551: Process is running
# Time 552: Trip from UVT to UPT
# Time 552: Bike broke down on the trip from UVT to UPT
# Time 552: Process is running
# Time 553: Process is running
# Time 554: Process is running
# Time 555: Process is running
# Time 556: Process is running
# Time 557: Process is running
# Time 558: Process is running
# Time 559: Process is running
# Time 560: Process is running
# Time 561: Process is running
# Time 562: Process is running
# Time 563: Process is running
# Time 564: Process is running
# Time 565: Process is running
# Time 566: Process is running
# Time 567: Process is running
# Time 568: Trip from CENTER to UVT
# Time 568: Bike broke down on the trip from CENTER to UVT
# Time 568: Process is running
# Time 569: Process is running
# Time 570: Process is running
# Time 571: Process is running
# Time 572: Process is running
# Time 573: Process is running
# Time 574: Process is running
# Time 575: Process is running
# Time 576: Process is running
# Time 577: Process is running
# Time 578: Process is running
# Time 579: Process is running
# Time 580: Process is running
# Time 581: Process is running
# Time 582: Process is running
# Time 583: Process is running
# Time 584: Process is running
# Time 585: Process is running
# Time 586: Process is running
# Time 587: Trip from UVT to UPT
# Time 587: Process is running
# Time 588: Process is running
# Time 589: Process is running
# Time 590: Process is running
# Time 591: Process is running
# Time 592: Process is running
# Time 593: Process is running
# Time 594: Process is running
# Time 595: Process is running
# Time 596: Process is running
# Time 597: Process is running
# Time 598: Process is running
# Time 599: Process is running
# Time 600: Rebalancing bikes...
# UPT has 6 excess bikes.
# Moved 6 bikes from UPT to UVT.
# UVT has 7 excess bikes.
# Moved 6 bikes from UVT to UPT.
# Moved 1 bikes from UVT to CENTER.
# CENTER has 1 excess bikes.
# Moved 1 bikes from CENTER to UVT.
# Time 600: Process is running
# Time 601: Process is running
# Time 602: Trip from UVT to CENTER
# Time 602: Bike broke down on the trip from UVT to CENTER
# Time 602: Process is running
# Time 603: Process is running
# Time 604: Process is running
# Time 605: Process is running
# Time 606: Process is running
# Time 607: Process is running
# Time 608: Process is running
# Time 609: Process is running
# Time 610: Process is running
# Time 611: Process is running
# Time 612: Process is running
# Time 613: Process is running
# Time 614: Process is running
# Time 615: Process is running
# Time 616: Trip from UVT to UPT
# Time 616: Bike broke down on the trip from UVT to UPT
# Time 616: Process is running
# Time 617: Process is running
# Time 618: Process is running
# Time 619: Process is running
# Time 620: Process is running
# Time 621: Process is running
# Time 622: Process is running
# Time 623: Process is running
# Time 624: Process is running
# Time 625: Process is running
# Time 626: Process is running
# Time 627: Process is running
# Time 628: Process is running
# Time 629: Process is running
# Time 630: Process is running
# Time 631: Process is running
# Time 632: Process is running
# Time 633: Process is running
# Time 634: Trip from UVT to CENTER
# Time 634: Bike broke down on the trip from UVT to CENTER
# Time 634: Process is running
# Time 635: Process is running
# Time 636: Process is running
# Time 637: Process is running
# Time 638: Process is running
# Time 639: Process is running
# Time 640: Process is running
# Time 641: Process is running
# Time 642: Process is running
# Time 643: Process is running
# Time 644: Process is running
# Time 645: Trip from UPT to UVT
# Time 645: Customer unhappy. No bikes available at UPT.
# Time 645: Process is running
# Time 646: Process is running
# Time 647: Process is running
# Time 648: Process is running
# Time 649: Process is running
# Time 650: Process is running
# Time 651: Process is running
# Time 652: Process is running
# Time 653: Process is running
# Time 654: Process is running
# Time 655: Process is running
# Time 656: Process is running
# Time 657: Process is running
# Time 658: Trip from UVT to UPT
# Time 658: Process is running
# Time 659: Process is running
# Time 660: Rebalancing bikes...
# UPT has 6 excess bikes.
# Moved 6 bikes from UPT to UVT.
# UVT has 7 excess bikes.
# Moved 6 bikes from UVT to UPT.
# Moved 1 bikes from UVT to CENTER.
# CENTER has 1 excess bikes.
# Moved 1 bikes from CENTER to UVT.
# Time 660: Process is running
# Time 661: Process is running
# Time 662: Process is running
# Time 663: Process is running
# Time 664: Process is running
# Time 665: Process is running
# Time 666: Process is running
# Time 667: Process is running
# Time 668: Trip from UVT to UPT
# Time 668: Process is running
# Time 669: Process is running
# Time 670: Process is running
# Time 671: Process is running
# Time 672: Process is running
# Time 673: Process is running
# Time 674: Process is running
# Time 675: Process is running
# Time 676: Process is running
# Time 677: Process is running
# Time 678: Process is running
# Time 679: Process is running
# Time 680: Process is running
# Time 681: Process is running
# Time 682: Process is running
# Time 683: Process is running
# Time 684: Process is running
# Time 685: Process is running
# Time 686: Process is running
# Time 687: Process is running
# Time 688: Trip from UVT to UPT
# Time 688: Bike broke down on the trip from UVT to UPT
# Time 688: Process is running
# Time 689: Process is running
# Time 690: Process is running
# Time 691: Process is running
# Time 692: Process is running
# Time 693: Process is running
# Time 694: Process is running
# Time 695: Process is running
# Time 696: Process is running
# Time 697: Process is running
# Time 698: Process is running
# Time 699: Process is running
# Time 700: Process is running
# Time 701: Process is running
# Time 702: Process is running
# Time 703: Process is running
# Time 704: Trip from UVT to UPT
# Time 704: Process is running
# Time 705: Process is running
# Time 706: Process is running
# Time 707: Process is running
# Time 708: Process is running
# Time 709: Process is running
# Time 710: Process is running
# Time 711: Process is running
# Time 712: Process is running
# Time 713: Process is running
# Time 714: Process is running
# Time 715: Process is running
# Time 716: Process is running
# Time 717: Trip from CENTER to UVT
# Time 717: Process is running
# Time 718: Process is running
# Time 719: Process is running
# Time 720: Rebalancing bikes...
# UPT has 6 excess bikes.
# Moved 6 bikes from UPT to UVT.
# UVT has 7 excess bikes.
# Moved 6 bikes from UVT to UPT.
# Moved 1 bikes from UVT to CENTER.
# CENTER has 1 excess bikes.
# Moved 1 bikes from CENTER to UVT.
# Time 720: Process is running
# Time 721: Process is running
# Time 722: Process is running
# Time 723: Process is running
# Time 724: Process is running
# Time 725: Process is running
# Time 726: Process is running
# Time 727: Process is running
# Time 728: Trip from UVT to CENTER
# Time 728: Bike broke down on the trip from UVT to CENTER
# Time 728: Process is running
# Time 729: Process is running
# Time 730: Process is running
# Time 731: Process is running
# Time 732: Process is running
# Time 733: Process is running
# Time 734: Process is running
# Time 735: Process is running
# Time 736: Process is running
# Time 737: Process is running
# Time 738: Process is running
# Time 739: Process is running
# Time 740: Process is running
# Time 741: Process is running
# Time 742: Process is running
# Time 743: Process is running
# Time 744: Process is running
# Time 745: Process is running
# Time 746: Process is running
# Time 747: Trip from UPT to UVT
# Time 747: Customer unhappy. No bikes available at UPT.
# Time 747: Bike broke down on the trip from UPT to UVT
# Time 747: Process is running
# Time 748: Process is running
# Time 749: Process is running
# Time 750: Process is running
# Time 751: Process is running
# Time 752: Process is running
# Time 753: Process is running
# Time 754: Process is running
# Time 755: Process is running
# Time 756: Process is running
# Time 757: Process is running
# Time 758: Process is running
# Time 759: Process is running
# Time 760: Process is running
# Time 761: Process is running
# Time 762: Process is running
# Time 763: Process is running
# Time 764: Trip from PARK to UPT
# Time 764: Process is running
# Time 765: Process is running
# Time 766: Process is running
# Time 767: Process is running
# Time 768: Process is running
# Time 769: Process is running
# Time 770: Process is running
# Time 771: Process is running
# Time 772: Process is running
# Time 773: Process is running
# Time 774: Process is running
# Time 775: Process is running
# Time 776: Trip from UPT to UVT
# Time 776: Customer unhappy. No bikes available at UPT.
# Time 776: Bike broke down on the trip from UPT to UVT
# Time 776: Process is running
# Time 777: Process is running
# Time 778: Process is running
# Time 779: Process is running
# Time 780: Rebalancing bikes...
# UPT has 6 excess bikes.
# Moved 6 bikes from UPT to UVT.
# UVT has 7 excess bikes.
# Moved 6 bikes from UVT to UPT.
# Moved 1 bikes from UVT to CENTER.
# CENTER has 1 excess bikes.
# Moved 1 bikes from CENTER to UVT.
# Time 780: Process is running
# Time 781: Process is running
# Time 782: Process is running
# Time 783: Process is running
# Time 784: Process is running
# Time 785: Process is running
# Time 786: Process is running
# Time 787: Process is running
# Time 788: Process is running
# Time 789: Process is running
# Time 790: Process is running
# Time 791: Process is running
# Time 792: Process is running
# Time 793: Process is running
# Time 794: Process is running
# Time 795: Trip from UPT to PARK
# Time 795: Customer unhappy. No bikes available at UPT.
# Time 795: Bike broke down on the trip from UPT to PARK
# Time 795: Process is running
# Time 796: Process is running
# Time 797: Process is running
# Time 798: Process is running
# Time 799: Process is running
# Time 800: Process is running
# Time 801: Process is running
# Time 802: Process is running
# Time 803: Process is running
# Time 804: Process is running
# Time 805: Process is running
# Time 806: Process is running
# Time 807: Process is running
# Time 808: Process is running
# Time 809: Process is running
# Time 810: Process is running
# Time 811: Process is running
# Time 812: Process is running
# Time 813: Process is running
# Time 814: Trip from UPT to PARK
# Time 814: Customer unhappy. No bikes available at UPT.
# Time 814: Bike broke down on the trip from UPT to PARK
# Time 814: Process is running
# Time 815: Process is running
# Time 816: Process is running
# Time 817: Process is running
# Time 818: Process is running
# Time 819: Process is running
# Time 820: Process is running
# Time 821: Process is running
# Time 822: Process is running
# Time 823: Process is running
# Time 824: Process is running
# Time 825: Process is running
# Time 826: Process is running
# Time 827: Process is running
# Time 828: Process is running
# Time 829: Process is running
# Time 830: Process is running
# Time 831: Trip from UPT to PARK
# Time 831: Customer unhappy. No bikes available at UPT.
# Time 831: Bike broke down on the trip from UPT to PARK
# Time 831: Process is running
# Time 832: Process is running
# Time 833: Process is running
# Time 834: Process is running
# Time 835: Process is running
# Time 836: Process is running
# Time 837: Process is running
# Time 838: Process is running
# Time 839: Process is running
# Time 840: Rebalancing bikes...
# UPT has 6 excess bikes.
# Moved 6 bikes from UPT to UVT.
# UVT has 7 excess bikes.
# Moved 6 bikes from UVT to UPT.
# Moved 1 bikes from UVT to CENTER.
# CENTER has 1 excess bikes.
# Moved 1 bikes from CENTER to UVT.
# Time 840: Process is running
# Time 841: Trip from UPT to UVT
# Time 841: Customer unhappy. No bikes available at UPT.
# Time 841: Process is running
# Time 842: Process is running
# Time 843: Process is running
# Time 844: Process is running
# Time 845: Process is running
# Time 846: Process is running
# Time 847: Process is running
# Time 848: Process is running
# Time 849: Process is running
# Time 850: Process is running
# Time 851: Process is running
# Time 852: Process is running
# Time 853: Process is running
# Time 854: Process is running
# Time 855: Process is running
# Time 856: Process is running
# Time 857: Trip from UVT to UPT
# Time 857: Process is running
# Time 858: Process is running
# Time 859: Process is running
# Time 860: Process is running
# Time 861: Process is running
# Time 862: Process is running
# Time 863: Process is running
# Time 864: Process is running
# Time 865: Process is running
# Time 866: Process is running
# Time 867: Process is running
# Time 868: Process is running
# Time 869: Process is running
# Time 870: Trip from CENTER to UVT
# Time 870: Bike broke down on the trip from CENTER to UVT
# Time 870: Process is running
# Time 871: Process is running
# Time 872: Process is running
# Time 873: Process is running
# Time 874: Process is running
# Time 875: Process is running
# Time 876: Process is running
# Time 877: Process is running
# Time 878: Process is running
# Time 879: Process is running
# Time 880: Process is running
# Time 881: Trip from CENTER to UVT
# Time 881: Bike broke down on the trip from CENTER to UVT
# Time 881: Process is running
# Time 882: Process is running
# Time 883: Process is running
# Time 884: Process is running
# Time 885: Process is running
# Time 886: Process is running
# Time 887: Process is running
# Time 888: Process is running
# Time 889: Process is running
# Time 890: Process is running
# Time 891: Process is running
# Time 892: Process is running
# Time 893: Process is running
# Time 894: Process is running
# Time 895: Process is running
# Time 896: Trip from UPT to PARK
# Time 896: Customer unhappy. No bikes available at UPT.
# Time 896: Bike broke down on the trip from UPT to PARK
# Time 896: Process is running
# Time 897: Process is running
# Time 898: Process is running
# Time 899: Process is running
# Time 900: Rebalancing bikes...
# UPT has 6 excess bikes.
# Moved 6 bikes from UPT to UVT.
# UVT has 7 excess bikes.
# Moved 6 bikes from UVT to UPT.
# Moved 1 bikes from UVT to CENTER.
# CENTER has 1 excess bikes.
# Moved 1 bikes from CENTER to UVT.
# Time 900: Process is running
# Time 901: Process is running
# Time 902: Process is running
# Time 903: Process is running
# Time 904: Process is running
# Time 905: Process is running
# Time 906: Process is running
# Time 907: Process is running
# Time 908: Process is running
# Time 909: Process is running
# Time 910: Process is running
# Time 911: Trip from PARK to UPT
# Time 911: Bike broke down on the trip from PARK to UPT
# Time 911: Process is running
# Time 912: Process is running
# Time 913: Process is running
# Time 914: Process is running
# Time 915: Process is running
# Time 916: Process is running
# Time 917: Process is running
# Time 918: Process is running
# Time 919: Process is running
# Time 920: Process is running
# Time 921: Process is running
# Time 922: Trip from UPT to UVT
# Time 922: Customer unhappy. No bikes available at UPT.
# Time 922: Bike broke down on the trip from UPT to UVT
# Time 922: Process is running
# Time 923: Process is running
# Time 924: Process is running
# Time 925: Process is running
# Time 926: Process is running
# Time 927: Process is running
# Time 928: Process is running
# Time 929: Process is running
# Time 930: Process is running
# Time 931: Process is running
# Time 932: Trip from UVT to CENTER
# Time 932: Process is running
# Time 933: Process is running
# Time 934: Process is running
# Time 935: Process is running
# Time 936: Process is running
# Time 937: Process is running
# Time 938: Process is running
# Time 939: Process is running
# Time 940: Process is running
# Time 941: Process is running
# Time 942: Process is running
# Time 943: Process is running
# Time 944: Process is running
# Time 945: Process is running
# Time 946: Process is running
# Time 947: Process is running
# Time 948: Trip from UVT to CENTER
# Time 948: Bike broke down on the trip from UVT to CENTER
# Time 948: Process is running
# Time 949: Process is running
# Time 950: Process is running
# Time 951: Process is running
# Time 952: Process is running
# Time 953: Process is running
# Time 954: Process is running
# Time 955: Process is running
# Time 956: Process is running
# Time 957: Process is running
# Time 958: Process is running
# Time 959: Process is running
# Time 960: Rebalancing bikes...
# UPT has 6 excess bikes.
# Moved 6 bikes from UPT to UVT.
# UVT has 7 excess bikes.
# Moved 6 bikes from UVT to UPT.
# Moved 1 bikes from UVT to CENTER.
# CENTER has 1 excess bikes.
# Moved 1 bikes from CENTER to UVT.
# Time 960: Process is running
# Time 961: Trip from PARK to UPT
# Time 961: Bike broke down on the trip from PARK to UPT
# Time 961: Process is running
# Time 962: Process is running
# Time 963: Process is running
# Time 964: Process is running
# Time 965: Process is running
# Time 966: Process is running
# Time 967: Process is running
# Time 968: Process is running
# Time 969: Process is running
# Time 970: Process is running
# Time 971: Trip from UPT to CENTER
# Time 971: Customer unhappy. No bikes available at UPT.
# Time 971: Process is running
# Time 972: Process is running
# Time 973: Process is running
# Time 974: Process is running
# Time 975: Process is running
# Time 976: Process is running
# Time 977: Process is running
# Time 978: Process is running
# Time 979: Process is running
# Time 980: Process is running
# Time 981: Process is running
# Time 982: Process is running
# Time 983: Process is running
# Time 984: Process is running
# Time 985: Trip from UPT to CENTER
# Time 985: Customer unhappy. No bikes available at UPT.
# Time 985: Bike broke down on the trip from UPT to CENTER
# Time 985: Process is running
# Time 986: Process is running
# Time 987: Process is running
# Time 988: Process is running
# Time 989: Process is running
# Time 990: Process is running
# Time 991: Process is running
# Time 992: Process is running
# Time 993: Process is running
# Time 994: Process is running
# Time 995: Trip from UPT to UVT
# Time 995: Customer unhappy. No bikes available at UPT.
# Time 995: Process is running
# Time 996: Process is running
# Time 997: Process is running
# Time 998: Process is running
# Time 999: Process is running
# Time 1000: Process is running
# Time 1001: Process is running
# Time 1002: Process is running
# Time 1003: Process is running
# Time 1004: Process is running
# Time 1005: Process is running
# Time 1006: Process is running
# Time 1007: Process is running
# Time 1008: Process is running
# Time 1009: Process is running
# Time 1010: Process is running
# Time 1011: Process is running
# Time 1012: Process is running
# Time 1013: Process is running
# Time 1014: Process is running
# Time 1015: Trip from UPT to PARK
# Time 1015: Customer unhappy. No bikes available at UPT.
# Time 1015: Process is running
# Time 1016: Process is running
# Time 1017: Process is running
# Time 1018: Process is running
# Time 1019: Process is running
# Time 1020: Rebalancing bikes...
# UPT has 6 excess bikes.
# Moved 6 bikes from UPT to UVT.
# UVT has 7 excess bikes.
# Moved 6 bikes from UVT to UPT.
# Moved 1 bikes from UVT to CENTER.
# CENTER has 1 excess bikes.
# Moved 1 bikes from CENTER to UVT.
# Time 1020: Process is running
# Time 1021: Process is running
# Time 1022: Process is running
# Time 1023: Process is running
# Time 1024: Process is running
# Time 1025: Process is running
# Time 1026: Process is running
# Time 1027: Process is running
# Time 1028: Trip from UPT to CENTER
# Time 1028: Customer unhappy. No bikes available at UPT.
# Time 1028: Process is running
# Time 1029: Process is running
# Time 1030: Process is running
# Time 1031: Process is running
# Time 1032: Process is running
# Time 1033: Process is running
# Time 1034: Process is running
# Time 1035: Process is running
# Time 1036: Process is running
# Time 1037: Process is running
# Time 1038: Process is running
# Time 1039: Process is running
# Time 1040: Process is running
# Time 1041: Process is running
# Time 1042: Process is running
# Time 1043: Process is running
# Time 1044: Process is running
# Time 1045: Trip from UVT to CENTER
# Time 1045: Bike broke down on the trip from UVT to CENTER
# Time 1045: Process is running
# Time 1046: Process is running
# Time 1047: Process is running
# Time 1048: Process is running
# Time 1049: Process is running
# Time 1050: Process is running
# Time 1051: Process is running
# Time 1052: Process is running
# Time 1053: Process is running
# Time 1054: Process is running
# Time 1055: Process is running
# Time 1056: Process is running
# Time 1057: Trip from PARK to UPT
# Time 1057: Process is running
# Time 1058: Process is running
# Time 1059: Process is running
# Time 1060: Process is running
# Time 1061: Process is running
# Time 1062: Process is running
# Time 1063: Process is running
# Time 1064: Process is running
# Time 1065: Process is running
# Time 1066: Process is running
# Time 1067: Process is running
# Time 1068: Process is running
# Time 1069: Process is running
# Time 1070: Process is running
# Time 1071: Process is running
# Time 1072: Process is running
# Time 1073: Trip from PARK to UPT
# Time 1073: Bike broke down on the trip from PARK to UPT
# Time 1073: Process is running
# Time 1074: Process is running
# Time 1075: Process is running
# Time 1076: Process is running
# Time 1077: Process is running
# Time 1078: Process is running
# Time 1079: Process is running
# Time 1080: Rebalancing bikes...
# UPT has 6 excess bikes.
# Moved 6 bikes from UPT to UVT.
# UVT has 7 excess bikes.
# Moved 6 bikes from UVT to UPT.
# Moved 1 bikes from UVT to CENTER.
# CENTER has 1 excess bikes.
# Moved 1 bikes from CENTER to UVT.
# Time 1080: Process is running
# Time 1081: Process is running
# Time 1082: Process is running
# Time 1083: Process is running
# Time 1084: Process is running
# Time 1085: Process is running
# Time 1086: Process is running
# Time 1087: Trip from UPT to UVT
# Time 1087: Customer unhappy. No bikes available at UPT.
# Time 1087: Process is running
# Time 1088: Process is running
# Time 1089: Process is running
# Time 1090: Process is running
# Time 1091: Process is running
# Time 1092: Process is running
# Time 1093: Process is running
# Time 1094: Process is running
# Time 1095: Process is running
# Time 1096: Process is running
# Time 1097: Process is running
# Time 1098: Process is running
# Time 1099: Trip from PARK to UPT
# Time 1099: Bike broke down on the trip from PARK to UPT
# Time 1099: Process is running
# Time 1100: Process is running
# Time 1101: Process is running
# Time 1102: Process is running
# Time 1103: Process is running
# Time 1104: Process is running
# Time 1105: Process is running
# Time 1106: Process is running
# Time 1107: Process is running
# Time 1108: Process is running
# Time 1109: Process is running
# Time 1110: Process is running
# Time 1111: Process is running
# Time 1112: Process is running
# Time 1113: Process is running
# Time 1114: Process is running
# Time 1115: Process is running
# Time 1116: Process is running
# Time 1117: Process is running
# Time 1118: Process is running
# Time 1119: Trip from UVT to UPT
# Time 1119: Process is running
# Time 1120: Process is running
# Time 1121: Process is running
# Time 1122: Process is running
# Time 1123: Process is running
# Time 1124: Process is running
# Time 1125: Process is running
# Time 1126: Process is running
# Time 1127: Process is running
# Time 1128: Process is running
# Time 1129: Process is running
# Time 1130: Process is running
# Time 1131: Process is running
# Time 1132: Process is running
# Time 1133: Process is running
# Time 1134: Process is running
# Time 1135: Process is running
# Time 1136: Process is running
# Time 1137: Process is running
# Time 1138: Trip from CENTER to UVT
# Time 1138: Bike broke down on the trip from CENTER to UVT
# Time 1138: Process is running
# Time 1139: Process is running
# Time 1140: Rebalancing bikes...
# UPT has 6 excess bikes.
# Moved 6 bikes from UPT to UVT.
# UVT has 7 excess bikes.
# Moved 6 bikes from UVT to UPT.
# Moved 1 bikes from UVT to CENTER.
# CENTER has 1 excess bikes.
# Moved 1 bikes from CENTER to UVT.
# Time 1140: Process is running
# Time 1141: Process is running
# Time 1142: Process is running
# Time 1143: Process is running
# Time 1144: Process is running
# Time 1145: Process is running
# Time 1146: Process is running
# Time 1147: Process is running
# Time 1148: Process is running
# Time 1149: Process is running
# Time 1150: Process is running
# Time 1151: Process is running
# Time 1152: Process is running
# Time 1153: Process is running
# Time 1154: Process is running
# Time 1155: Trip from UPT to PARK
# Time 1155: Customer unhappy. No bikes available at UPT.
# Time 1155: Bike broke down on the trip from UPT to PARK
# Time 1155: Process is running
# Time 1156: Process is running
# Time 1157: Process is running
# Time 1158: Process is running
# Time 1159: Process is running
# Time 1160: Process is running
# Time 1161: Process is running
# Time 1162: Process is running
# Time 1163: Process is running
# Time 1164: Process is running
# Time 1165: Process is running
# Time 1166: Process is running
# Time 1167: Process is running
# Time 1168: Process is running
# Time 1169: Process is running
# Time 1170: Process is running
# Time 1171: Process is running
# Time 1172: Process is running
# Time 1173: Process is running
# Time 1174: Process is running
# Time 1175: Trip from UVT to UPT
# Time 1175: Bike broke down on the trip from UVT to UPT
# Time 1175: Process is running
# Time 1176: Process is running
# Time 1177: Process is running
# Time 1178: Process is running
# Time 1179: Process is running
# Time 1180: Process is running
# Time 1181: Process is running
# Time 1182: Process is running
# Time 1183: Process is running
# Time 1184: Process is running
# Time 1185: Process is running
# Time 1186: Trip from UVT to UPT
# Time 1186: Bike broke down on the trip from UVT to UPT
# Time 1186: Process is running
# Time 1187: Process is running
# Time 1188: Process is running
# Time 1189: Process is running
# Time 1190: Process is running
# Time 1191: Process is running
# Time 1192: Process is running
# Time 1193: Process is running
# Time 1194: Process is running
# Time 1195: Process is running
# Time 1196: Trip from CENTER to UPT
# Time 1196: Bike broke down on the trip from CENTER to UPT
# Time 1196: Process is running
# Time 1197: Process is running
# Time 1198: Process is running
# Time 1199: Process is running
# Time 1200: Rebalancing bikes...
# UPT has 6 excess bikes.
# Moved 6 bikes from UPT to UVT.
# UVT has 7 excess bikes.
# Moved 6 bikes from UVT to UPT.
# Moved 1 bikes from UVT to CENTER.
# CENTER has 1 excess bikes.
# Moved 1 bikes from CENTER to UVT.
# Time 1200: Process is running
# Time 1201: Process is running
# Time 1202: Process is running
# Time 1203: Process is running
# Time 1204: Process is running
# Time 1205: Process is running
# Time 1206: Process is running
# Time 1207: Trip from UPT to CENTER
# Time 1207: Customer unhappy. No bikes available at UPT.
# Time 1207: Bike broke down on the trip from UPT to CENTER
# Time 1207: Process is running
# Time 1208: Process is running
# Time 1209: Process is running
# Time 1210: Process is running
# Time 1211: Process is running
# Time 1212: Process is running
# Time 1213: Process is running
# Time 1214: Process is running
# Time 1215: Process is running
# Time 1216: Process is running
# Time 1217: Trip from UVT to UPT
# Time 1217: Process is running
# Time 1218: Process is running
# Time 1219: Process is running
# Time 1220: Process is running
# Time 1221: Process is running
# Time 1222: Process is running
# Time 1223: Process is running
# Time 1224: Process is running
# Time 1225: Process is running
# Time 1226: Process is running
# Time 1227: Process is running
# Time 1228: Process is running
# Time 1229: Process is running
# Time 1230: Process is running
# Time 1231: Process is running
# Time 1232: Process is running
# Time 1233: Process is running
# Time 1234: Trip from PARK to UPT
# Time 1234: Bike broke down on the trip from PARK to UPT
# Time 1234: Process is running
# Time 1235: Process is running
# Time 1236: Process is running
# Time 1237: Process is running
# Time 1238: Process is running
# Time 1239: Process is running
# Time 1240: Process is running
# Time 1241: Process is running
# Time 1242: Process is running
# Time 1243: Process is running
# Time 1244: Process is running
# Time 1245: Process is running
# Time 1246: Process is running
# Time 1247: Process is running
# Time 1248: Process is running
# Time 1249: Process is running
# Time 1250: Process is running
# Time 1251: Process is running
# Time 1252: Process is running
# Time 1253: Process is running
# Time 1254: Trip from UVT to CENTER
# Time 1254: Process is running
# Time 1255: Process is running
# Time 1256: Process is running
# Time 1257: Process is running
# Time 1258: Process is running
# Time 1259: Process is running
# Time 1260: Rebalancing bikes...
# UPT has 6 excess bikes.
# Moved 6 bikes from UPT to UVT.
# UVT has 7 excess bikes.
# Moved 6 bikes from UVT to UPT.
# Moved 1 bikes from UVT to CENTER.
# CENTER has 1 excess bikes.
# Moved 1 bikes from CENTER to UVT.
# Time 1260: Process is running
# Time 1261: Process is running
# Time 1262: Process is running
# Time 1263: Process is running
# Time 1264: Process is running
# Time 1265: Process is running
# Time 1266: Process is running
# Time 1267: Process is running
# Time 1268: Process is running
# Time 1269: Process is running
# Time 1270: Process is running
# Time 1271: Process is running
# Time 1272: Process is running
# Time 1273: Trip from UPT to PARK
# Time 1273: Customer unhappy. No bikes available at UPT.
# Time 1273: Bike broke down on the trip from UPT to PARK
# Time 1273: Process is running
# Time 1274: Process is running
# Time 1275: Process is running
# Time 1276: Process is running
# Time 1277: Process is running
# Time 1278: Process is running
# Time 1279: Process is running
# Time 1280: Process is running
# Time 1281: Process is running
# Time 1282: Process is running
# Time 1283: Process is running
# Time 1284: Process is running
# Time 1285: Process is running
# Time 1286: Process is running
# Time 1287: Process is running
# Time 1288: Process is running
# Time 1289: Process is running
# Time 1290: Process is running
# Time 1291: Process is running
# Time 1292: Process is running
# Time 1293: Trip from CENTER to UPT
# Time 1293: Process is running
# Time 1294: Process is running
# Time 1295: Process is running
# Time 1296: Process is running
# Time 1297: Process is running
# Time 1298: Process is running
# Time 1299: Process is running
# Time 1300: Process is running
# Time 1301: Process is running
# Time 1302: Process is running
# Time 1303: Process is running
# Time 1304: Process is running
# Time 1305: Process is running
# Time 1306: Process is running
# Time 1307: Trip from UPT to CENTER
# Time 1307: Customer unhappy. No bikes available at UPT.
# Time 1307: Process is running
# Time 1308: Process is running
# Time 1309: Process is running
# Time 1310: Process is running
# Time 1311: Process is running
# Time 1312: Process is running
# Time 1313: Process is running
# Time 1314: Process is running
# Time 1315: Process is running
# Time 1316: Process is running
# Time 1317: Process is running
# Time 1318: Process is running
# Time 1319: Process is running
# Time 1320: Rebalancing bikes...
# UPT has 6 excess bikes.
# Moved 6 bikes from UPT to UVT.
# UVT has 7 excess bikes.
# Moved 6 bikes from UVT to UPT.
# Moved 1 bikes from UVT to CENTER.
# CENTER has 1 excess bikes.
# Moved 1 bikes from CENTER to UVT.
# Time 1320: Process is running
# Time 1321: Process is running
# Time 1322: Trip from UPT to UVT
# Time 1322: Customer unhappy. No bikes available at UPT.
# Time 1322: Bike broke down on the trip from UPT to UVT
# Time 1322: Process is running
# Time 1323: Process is running
# Time 1324: Process is running
# Time 1325: Process is running
# Time 1326: Process is running
# Time 1327: Process is running
# Time 1328: Process is running
# Time 1329: Process is running
# Time 1330: Process is running
# Time 1331: Process is running
# Time 1332: Process is running
# Time 1333: Process is running
# Time 1334: Process is running
# Time 1335: Process is running
# Time 1336: Process is running
# Time 1337: Process is running
# Time 1338: Process is running
# Time 1339: Trip from UPT to PARK
# Time 1339: Customer unhappy. No bikes available at UPT.
# Time 1339: Process is running
# Time 1340: Process is running
# Time 1341: Process is running
# Time 1342: Process is running
# Time 1343: Process is running
# Time 1344: Process is running
# Time 1345: Process is running
# Time 1346: Process is running
# Time 1347: Process is running
# Time 1348: Process is running
# Time 1349: Process is running
# Time 1350: Process is running
# Time 1351: Process is running
# Time 1352: Process is running
# Time 1353: Trip from UPT to CENTER
# Time 1353: Customer unhappy. No bikes available at UPT.
# Time 1353: Process is running
# Time 1354: Process is running
# Time 1355: Process is running
# Time 1356: Process is running
# Time 1357: Process is running
# Time 1358: Process is running
# Time 1359: Process is running
# Time 1360: Process is running
# Time 1361: Process is running
# Time 1362: Process is running
# Time 1363: Process is running
# Time 1364: Process is running
# Time 1365: Process is running
# Time 1366: Process is running
# Time 1367: Process is running
# Time 1368: Process is running
# Time 1369: Process is running
# Time 1370: Trip from PARK to UPT
# Time 1370: Bike broke down on the trip from PARK to UPT
# Time 1370: Process is running
# Time 1371: Process is running
# Time 1372: Process is running
# Time 1373: Process is running
# Time 1374: Process is running
# Time 1375: Process is running
# Time 1376: Process is running
# Time 1377: Process is running
# Time 1378: Process is running
# Time 1379: Process is running
# Time 1380: Rebalancing bikes...
# UPT has 6 excess bikes.
# Moved 6 bikes from UPT to UVT.
# UVT has 7 excess bikes.
# Moved 6 bikes from UVT to UPT.
# Moved 1 bikes from UVT to CENTER.
# CENTER has 1 excess bikes.
# Moved 1 bikes from CENTER to UVT.
# Time 1380: Process is running
# Time 1381: Process is running
# Time 1382: Process is running
# Time 1383: Process is running
# Time 1384: Process is running
# Time 1385: Process is running
# Time 1386: Process is running
# Time 1387: Process is running
# Time 1388: Trip from CENTER to UVT
# Time 1388: Bike broke down on the trip from CENTER to UVT
# Time 1388: Process is running
# Time 1389: Process is running
# Time 1390: Process is running
# Time 1391: Process is running
# Time 1392: Process is running
# Time 1393: Process is running
# Time 1394: Process is running
# Time 1395: Process is running
# Time 1396: Process is running
# Time 1397: Process is running
# Time 1398: Process is running
# Time 1399: Process is running
# Time 1400: Process is running
# Time 1401: Process is running
# Time 1402: Trip from PARK to UPT
# Time 1402: Bike broke down on the trip from PARK to UPT
# Time 1402: Process is running
# Time 1403: Process is running
# Time 1404: Process is running
# Time 1405: Process is running
# Time 1406: Process is running
# Time 1407: Process is running
# Time 1408: Process is running
# Time 1409: Process is running
# Time 1410: Process is running
# Time 1411: Process is running
# Time 1412: Process is running
# Time 1413: Process is running
# Time 1414: Trip from PARK to UPT
# Time 1414: Bike broke down on the trip from PARK to UPT
# Time 1414: Process is running
# Time 1415: Process is running
# Time 1416: Process is running
# Time 1417: Process is running
# Time 1418: Process is running
# Time 1419: Process is running
# Time 1420: Process is running
# Time 1421: Process is running
# Time 1422: Process is running
# Time 1423: Process is running
# Time 1424: Process is running
# Time 1425: Process is running
# Time 1426: Process is running
# Time 1427: Process is running
# Time 1428: Process is running
# Time 1429: Process is running
# Time 1430: Trip from PARK to UPT
# Time 1430: Process is running
# Time 1431: Process is running
# Time 1432: Process is running
# Time 1433: Process is running
# Time 1434: Process is running
# Time 1435: Process is running
# Time 1436: Process is running
# Time 1437: Process is running
# Time 1438: Process is running
# Time 1439: Process is running
#
# Unhappy customers who could not rent a bike: 31
# Unhappy customers who could not return a bike due to full stations: 0

# %%
import simpy
import random
import matplotlib.pyplot as plt

# The Environment in SimPy manages the simulation time and handles event scheduling.
env = simpy.Environment()

# Defining the Station Class
class Station:
    def __init__(self, env, name, capacity, init_bikes):
        self.env = env
        self.name = name
        self.capacity = capacity
        self.bikes = simpy.Container(env, init=init_bikes, capacity=capacity)

    def available_space(self):
        """Returns the number of available spaces at the station."""
        return self.capacity - self.bikes.level

    def return_bike(self):
        """Returns a repaired bike to the station."""
        if self.bikes.level < self.capacity:
            yield self.bikes.put(1)  # Put the bike back into the station's container
            print(f"Time {self.env.now}: Repaired bike returned to {self.name}. Bikes at station: {self.bikes.level}")
        else:
            print(f"Time {self.env.now}: {self.name} is full. Cannot return repaired bike.")
            maintenance.unhappy_customers_full_station += 1  # Increment unhappy customer counter

# Create stations
UPT_station = Station(env, "UPT", capacity=10, init_bikes=10)
UVT_station = Station(env, "UVT", capacity=15, init_bikes=8)
CENTER_station = Station(env, "CENTER", capacity=12, init_bikes=6)
PARK_station = Station(env, "PARK", capacity=8, init_bikes=0)

stations = [UPT_station, UVT_station, CENTER_station, PARK_station]

# Defining the Maintenance class
class Maintenance:
    def __init__(self):
        self.repaired_bikes = []
        self.rebalance_interval = 60  # Rebalance every 60 minutes
        self.unhappy_customers_rent = 0  # Count of unhappy customers who cannot rent bikes
        self.unhappy_customers_full_station = 0  # Count of unhappy customers who cannot return bikes
        self.bikes_under_maintenance = 0  # Count of bikes currently under maintenance

    def repair_bike(self, bike):
        """Simulate bike repair and add it to the repaired bikes list."""
        self.repaired_bikes.append(bike)
        self.bikes_under_maintenance += 1  # Increment maintenance count

    def return_repaired_bikes(self):
        """Return repaired bikes to stations with available space."""
        for bike in self.repaired_bikes:
            for station in stations:
                if station.available_space() > 0:
                    env.process(station.return_bike())  # Return bike to the station
                    break  # Move on to the next bike after successfully returning
            else:
                print(f"Time {env.now}: No available space for bike {bike}.")  # No space found for this bike

        # Clear the repaired bikes list after returning
        self.repaired_bikes.clear()
        self.bikes_under_maintenance = 0  # Reset maintenance count after returning

    def rebalance(self):
        """Rebalance bikes among stations every defined interval."""
        while True:
            yield env.timeout(self.rebalance_interval)
            print(f"Time {env.now}: Rebalancing bikes...")

            # Calculate average bikes across all stations
            total_bikes = sum(station.bikes.level for station in stations)
            average_bikes = total_bikes // len(stations)  # Use integer division

            for station in stations:
                if station.bikes.level > average_bikes:  # This station has excess bikes
                    excess_bikes = station.bikes.level - average_bikes
                    print(f"{station.name} has {excess_bikes} excess bikes.")

                    # Move excess bikes to stations that need them
                    for other_station in stations:
                        if other_station != station and other_station.available_space() > 0:
                            bikes_to_move = min(excess_bikes, other_station.available_space())
                            station.bikes.get(bikes_to_move)  # Remove bikes from the current station
                            other_station.bikes.put(bikes_to_move)  # Add bikes to the other station
                            print(f"Moved {bikes_to_move} bikes from {station.name} to {other_station.name}.")
                            excess_bikes -= bikes_to_move
                            if excess_bikes <= 0:
                                break

# Initialize maintenance
maintenance = Maintenance()

bike_failure_probability = 0.50  # 50% chance of a bike breaking down during a trip

# Define time slots for a single day and trip probabilities
time_slots = [
    {
        'name': 'morning_start',
        'start': 0,
        'end': 120,
        'prob_matrix': {
            ('UPT', 'UVT'): 0.4,
            ('UVT', 'UPT'): 0.6,
            ('UPT', 'CENTER'): 0.2,
            ('CENTER', 'UPT'): 0.5,
            ('UVT', 'CENTER'): 0.3,
            ('CENTER', 'UVT'): 0.4,
            ('UPT', 'PARK'): 0.3,
            ('PARK', 'UPT'): 0.2,
        }
    },
    {
        'name': 'midday',
        'start': 120,
        'end': 720,
        'prob_matrix': {
            ('UPT', 'UVT'): 0.2,
            ('UVT', 'UPT'): 0.3,
            ('UPT', 'CENTER'): 0.1,
            ('CENTER', 'UPT'): 0.2,
            ('UVT', 'CENTER'): 0.25,
            ('CENTER', 'UVT'): 0.35,
            ('UPT', 'PARK'): 0.15,
            ('PARK', 'UPT'): 0.25,
        }
    }
]

# Define a default probability matrix for times that don't match any time slot
default_prob_matrix = {
    ('UPT', 'UVT'): 0.05,
    ('UVT', 'UPT'): 0.05,
    ('UPT', 'CENTER'): 0.05,
    ('CENTER', 'UPT'): 0.05,
    ('UVT', 'CENTER'): 0.05,
    ('CENTER', 'UVT'): 0.05,
    ('UPT', 'PARK'): 0.05,
    ('PARK', 'UPT'): 0.05,
}

# Function to get the probability matrix based on current time
def get_prob_matrix(current_time):
    for slot in time_slots:
        if slot['start'] <= current_time < slot['end']:
            return slot['prob_matrix']
    return default_prob_matrix

# Initialize lists for data collection
bike_levels_data = {station.name: [] for station in stations}
maintenance_data = []
customer_satisfaction_data = {'rent_unhappy': [], 'return_unhappy': []}

# Function to collect data at each time step
def collect_data():
    # Collect bike levels
    for station in stations:
        bike_levels_data[station.name].append(station.bikes.level)

    # Collect maintenance data
    maintenance_data.append(maintenance.bikes_under_maintenance)

    # Collect customer satisfaction data
    customer_satisfaction_data['rent_unhappy'].append(maintenance.unhappy_customers_rent)
    customer_satisfaction_data['return_unhappy'].append(maintenance.unhappy_customers_full_station)

# Function to generate a trip
def generate_trip(env, stations, maintenance):
    while True:
        current_time = env.now % 1440
        prob_matrix = get_prob_matrix(current_time)

        trips = list(prob_matrix.keys())
        probabilities = list(prob_matrix.values())
        trip = random.choices(trips, probabilities)[0]

        origin, destination = trip
        print(f"Time {env.now}: Trip from {origin} to {destination}")

        # Check if there are bikes available to rent
        if stations[next(i for i, station in enumerate(stations) if station.name == origin)].available_space() == 0:
            print(f"Time {env.now}: Customer unhappy. No bikes available at {origin}.")
            maintenance.unhappy_customers_rent += 1  # Increment unhappy customer counter

        if random.random() < bike_failure_probability:
            print(f"Time {env.now}: Bike broke down on the trip from {origin} to {destination}")
            maintenance.repair_bike("Bike")  # Repair the broken bike

        trip_duration = random.randint(10, 20)
        yield env.timeout(trip_duration)

        # Collect data after each trip
        collect_data()

# Start the trip generation process
env.process(generate_trip(env, stations, maintenance))

# Start the rebalancing process
env.process(maintenance.rebalance())

# Run the simulation for 24 hours (1440 minutes)
env.run(until=1440)

# Print final statistics
print("\nFinal statistics:")
print("Bike levels at each station:")
for station in stations:
    print(f"{station.name}: {station.bikes.level}")

print(f"Unhappy customers due to unavailable bikes: {maintenance.unhappy_customers_rent}")
print(f"Unhappy customers due to full stations: {maintenance.unhappy_customers_full_station}")

# Visualization
plt.figure(figsize=(15, 10))

# Plot bike levels at each station
plt.subplot(3, 1, 1)
for station_name, levels in bike_levels_data.items():
    plt.plot(levels, label=station_name)
plt.title('Bike Levels at Each Station Over Time')
plt.xlabel('Time (minutes)')
plt.ylabel('Number of Bikes')
plt.legend()

# Plot number of bikes under maintenance
plt.subplot(3, 1, 2)
plt.plot(maintenance_data, label='Bikes Under Maintenance')
plt.title('Bikes Under Maintenance Over Time')
plt.xlabel('Time (minutes)')
plt.ylabel('Number of Bikes')
plt.legend()

# Plot customer satisfaction metrics
plt.subplot(3, 1, 3)
plt.plot(customer_satisfaction_data['rent_unhappy'], label='Unhappy Customers Renting')
plt.plot(customer_satisfaction_data['return_unhappy'], label='Unhappy Customers Returning')
plt.title('Customer Satisfaction Metrics Over Time')
plt.xlabel('Time (minutes)')
plt.ylabel('Number of Unhappy Customers')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Time 0: Trip from UPT to PARK
# Time 0: Customer unhappy. No bikes available at UPT.
# Time 0: Bike broke down on the trip from UPT to PARK
# Time 12: Trip from UPT to UVT
# Time 12: Customer unhappy. No bikes available at UPT.
# Time 12: Bike broke down on the trip from UPT to UVT
# Time 28: Trip from UPT to UVT
# Time 28: Customer unhappy. No bikes available at UPT.
# Time 28: Bike broke down on the trip from UPT to UVT
# Time 39: Trip from UVT to UPT
# Time 39: Bike broke down on the trip from UVT to UPT
# Time 56: Trip from UVT to CENTER
# Time 56: Bike broke down on the trip from UVT to CENTER
# Time 60: Rebalancing bikes...
# UPT has 4 excess bikes.
# Moved 4 bikes from UPT to UVT.
# UVT has 6 excess bikes.
# Moved 4 bikes from UVT to UPT.
# Moved 2 bikes from UVT to CENTER.
# CENTER has 2 excess bikes.
# Moved 2 bikes from CENTER to UVT.
# Time 68: Trip from UVT to CENTER
# Time 68: Bike broke down on the trip from UVT to CENTER
# Time 84: Trip from CENTER to UPT
# Time 84: Bike broke down on the trip from CENTER to UPT
# Time 96: Trip from UVT to CENTER
# Time 109: Trip from CENTER to UPT
# Time 109: Bike broke down on the trip from CENTER to UPT
# Time 120: Rebalancing bikes...
# UPT has 4 excess bikes.
# Moved 4 bikes from UPT to UVT.
# UVT has 6 excess bikes.
# Moved 4 bikes from UVT to UPT.
# Moved 2 bikes from UVT to CENTER.
# CENTER has 2 excess bikes.
# Moved 2 bikes from CENTER to UVT.
# Time 125: Trip from CENTER to UVT
# Time 141: Trip from CENTER to UPT
# Time 153: Trip from CENTER to UVT
# Time 164: Trip from UVT to CENTER
# Time 164: Bike broke down on the trip from UVT to CENTER
# Time 177: Trip from UVT to CENTER
# Time 177: Bike broke down on the trip from UVT to CENTER
# Time 180: Rebalancing bikes...
# UPT has 4 excess bikes.
# Moved 4 bikes from UPT to UVT.
# UVT has 6 excess bikes.
# Moved 4 bikes from UVT to UPT.
# Moved 2 bikes from UVT to CENTER.
# CENTER has 2 excess bikes.
# Moved 2 bikes from CENTER to UVT.
# Time 193: Trip from UPT to CENTER
# Time 193: Customer unhappy. No bikes available at UPT.
# Time 210: Trip from PARK to UPT
# Time 210: Bike broke down on the trip from PARK to UPT
# Time 220: Trip from UPT to UVT
# Time 220: Customer unhappy. No bikes available at UPT.
# Time 220: Bike broke down on the trip from UPT to UVT
# Time 234: Trip from UPT to UVT
# Time 234: Customer unhappy. No bikes available at UPT.
# Time 234: Bike broke down on the trip from UPT to UVT
# Time 240: Rebalancing bikes...
# UPT has 4 excess bikes.
# Moved 4 bikes from UPT to UVT.
# UVT has 6 excess bikes.
# Moved 4 bikes from UVT to UPT.
# Moved 2 bikes from UVT to CENTER.
# CENTER has 2 excess bikes.
# Moved 2 bikes from CENTER to UVT.
# Time 249: Trip from UVT to UPT
# Time 249: Bike broke down on the trip from UVT to UPT
# Time 260: Trip from UPT to PARK
# Time 260: Customer unhappy. No bikes available at UPT.
# Time 260: Bike broke down on the trip from UPT to PARK
# Time 270: Trip from UVT to UPT
# Time 270: Bike broke down on the trip from UVT to UPT
# Time 287: Trip from UPT to UVT
# Time 287: Customer unhappy. No bikes available at UPT.
# Time 287: Bike broke down on the trip from UPT to UVT
# Time 300: Rebalancing bikes...
# UPT has 4 excess bikes.
# Moved 4 bikes from UPT to UVT.
# UVT has 6 excess bikes.
# Moved 4 bikes from UVT to UPT.
# Moved 2 bikes from UVT to CENTER.
# CENTER has 2 excess bikes.
# Moved 2 bikes from CENTER to UVT.
# Time 302: Trip from PARK to UPT
# Time 314: Trip from CENTER to UPT
# Time 331: Trip from UVT to CENTER
# Time 344: Trip from CENTER to UPT
# Time 357: Trip from PARK to UPT
# Time 360: Rebalancing bikes...
# UPT has 4 excess bikes.
# Moved 4 bikes from UPT to UVT.
# UVT has 6 excess bikes.
# Moved 4 bikes from UVT to UPT.
# Moved 2 bikes from UVT to CENTER.
# CENTER has 2 excess bikes.
# Moved 2 bikes from CENTER to UVT.
# Time 374: Trip from UVT to UPT
# Time 374: Bike broke down on the trip from UVT to UPT
# Time 389: Trip from CENTER to UVT
# Time 407: Trip from PARK to UPT
# Time 419: Trip from UVT to UPT
# Time 419: Bike broke down on the trip from UVT to UPT
# Time 420: Rebalancing bikes...
# UPT has 4 excess bikes.
# Moved 4 bikes from UPT to UVT.
# UVT has 6 excess bikes.
# Moved 4 bikes from UVT to UPT.
# Moved 2 bikes from UVT to CENTER.
# CENTER has 2 excess bikes.
# Moved 2 bikes from CENTER to UVT.
# Time 432: Trip from UVT to UPT
# Time 447: Trip from UPT to CENTER
# Time 447: Customer unhappy. No bikes available at UPT.
# Time 460: Trip from PARK to UPT
# Time 460: Bike broke down on the trip from PARK to UPT
# Time 470: Trip from PARK to UPT
# Time 480: Rebalancing bikes...
# UPT has 4 excess bikes.
# Moved 4 bikes from UPT to UVT.
# UVT has 6 excess bikes.
# Moved 4 bikes from UVT to UPT.
# Moved 2 bikes from UVT to CENTER.
# CENTER has 2 excess bikes.
# Moved 2 bikes from CENTER to UVT.
# Time 481: Trip from CENTER to UVT
# Time 481: Bike broke down on the trip from CENTER to UVT
# Time 501: Trip from PARK to UPT
# Time 501: Bike broke down on the trip from PARK to UPT
# Time 511: Trip from CENTER to UVT
# Time 511: Bike broke down on the trip from CENTER to UVT
# Time 523: Trip from PARK to UPT
# Time 540: Rebalancing bikes...
# UPT has 4 excess bikes.
# Moved 4 bikes from UPT to UVT.
# UVT has 6 excess bikes.
# Moved 4 bikes from UVT to UPT.
# Moved 2 bikes from UVT to CENTER.
# CENTER has 2 excess bikes.
# Moved 2 bikes from CENTER to UVT.
# Time 541: Trip from UPT to PARK
# Time 541: Customer unhappy. No bikes available at UPT.
# Time 541: Bike broke down on the trip from UPT to PARK
# Time 560: Trip from CENTER to UPT
# Time 560: Bike broke down on the trip from CENTER to UPT
# Time 570: Trip from UVT to CENTER
# Time 570: Bike broke down on the trip from UVT to CENTER
# Time 585: Trip from CENTER to UPT
# Time 585: Bike broke down on the trip from CENTER to UPT
# Time 597: Trip from UVT to UPT
# Time 600: Rebalancing bikes...
# UPT has 4 excess bikes.
# Moved 4 bikes from UPT to UVT.
# UVT has 6 excess bikes.
# Moved 4 bikes from UVT to UPT.
# Moved 2 bikes from UVT to CENTER.
# CENTER has 2 excess bikes.
# Moved 2 bikes from CENTER to UVT.
# Time 607: Trip from CENTER to UVT
# Time 607: Bike broke down on the trip from CENTER to UVT
# Time 621: Trip from UVT to UPT
# Time 621: Bike broke down on the trip from UVT to UPT
# Time 638: Trip from UVT to UPT
# Time 638: Bike broke down on the trip from UVT to UPT
# Time 657: Trip from CENTER to UVT
# Time 657: Bike broke down on the trip from CENTER to UVT
# Time 660: Rebalancing bikes...
# UPT has 4 excess bikes.
# Moved 4 bikes from UPT to UVT.
# UVT has 6 excess bikes.
# Moved 4 bikes from UVT to UPT.
# Moved 2 bikes from UVT to CENTER.
# CENTER has 2 excess bikes.
# Moved 2 bikes from CENTER to UVT.
# Time 675: Trip from PARK to UPT
# Time 675: Bike broke down on the trip from PARK to UPT
# Time 690: Trip from CENTER to UVT
# Time 710: Trip from PARK to UPT
# Time 720: Rebalancing bikes...
# UPT has 4 excess bikes.
# Moved 4 bikes from UPT to UVT.
# UVT has 6 excess bikes.
# Moved 4 bikes from UVT to UPT.
# Moved 2 bikes from UVT to CENTER.
# CENTER has 2 excess bikes.
# Moved 2 bikes from CENTER to UVT.
# Time 728: Trip from UVT to UPT
# Time 728: Bike broke down on the trip from UVT to UPT
# Time 747: Trip from UPT to PARK
# Time 747: Customer unhappy. No bikes available at UPT.
# Time 747: Bike broke down on the trip from UPT to PARK
# Time 765: Trip from UPT to UVT
# Time 765: Customer unhappy. No bikes available at UPT.
# Time 777: Trip from UPT to UVT
# Time 777: Customer unhappy. No bikes available at UPT.
# Time 777: Bike broke down on the trip from UPT to UVT
# Time 780: Rebalancing bikes...
# UPT has 4 excess bikes.
# Moved 4 bikes from UPT to UVT.
# UVT has 6 excess bikes.
# Moved 4 bikes from UVT to UPT.
# Moved 2 bikes from UVT to CENTER.
# CENTER has 2 excess bikes.
# Moved 2 bikes from CENTER to UVT.
# Time 796: Trip from UPT to PARK
# Time 796: Customer unhappy. No bikes available at UPT.
# Time 807: Trip from PARK to UPT
# Time 820: Trip from UPT to CENTER
# Time 820: Customer unhappy. No bikes available at UPT.
# Time 836: Trip from UPT to CENTER
# Time 836: Customer unhappy. No bikes available at UPT.
# Time 840: Rebalancing bikes...
# UPT has 4 excess bikes.
# Moved 4 bikes from UPT to UVT.
# UVT has 6 excess bikes.
# Moved 4 bikes from UVT to UPT.
# Moved 2 bikes from UVT to CENTER.
# CENTER has 2 excess bikes.
# Moved 2 bikes from CENTER to UVT.
# Time 852: Trip from UVT to CENTER
# Time 852: Bike broke down on the trip from UVT to CENTER
# Time 871: Trip from UPT to PARK
# Time 871: Customer unhappy. No bikes available at UPT.
# Time 889: Trip from UPT to PARK
# Time 889: Customer unhappy. No bikes available at UPT.
# Time 889: Bike broke down on the trip from UPT to PARK
# Time 900: Rebalancing bikes...
# UPT has 4 excess bikes.
# Moved 4 bikes from UPT to UVT.
# UVT has 6 excess bikes.
# Moved 4 bikes from UVT to UPT.
# Moved 2 bikes from UVT to CENTER.
# CENTER has 2 excess bikes.
# Moved 2 bikes from CENTER to UVT.
# Time 908: Trip from UPT to UVT
# Time 908: Customer unhappy. No bikes available at UPT.
# Time 927: Trip from UVT to CENTER
# Time 927: Bike broke down on the trip from UVT to CENTER
# Time 945: Trip from UPT to CENTER
# Time 945: Customer unhappy. No bikes available at UPT.
# Time 945: Bike broke down on the trip from UPT to CENTER
# Time 960: Rebalancing bikes...
# UPT has 4 excess bikes.
# Moved 4 bikes from UPT to UVT.
# UVT has 6 excess bikes.
# Moved 4 bikes from UVT to UPT.
# Moved 2 bikes from UVT to CENTER.
# CENTER has 2 excess bikes.
# Moved 2 bikes from CENTER to UVT.
# Time 964: Trip from UPT to UVT
# Time 964: Customer unhappy. No bikes available at UPT.
# Time 964: Bike broke down on the trip from UPT to UVT
# Time 974: Trip from CENTER to UVT
# Time 974: Bike broke down on the trip from CENTER to UVT
# Time 985: Trip from UPT to CENTER
# Time 985: Customer unhappy. No bikes available at UPT.
# Time 985: Bike broke down on the trip from UPT to CENTER
# Time 1003: Trip from UVT to CENTER
# Time 1003: Bike broke down on the trip from UVT to CENTER
# Time 1020: Rebalancing bikes...
# UPT has 4 excess bikes.
# Moved 4 bikes from UPT to UVT.
# UVT has 6 excess bikes.
# Moved 4 bikes from UVT to UPT.
# Moved 2 bikes from UVT to CENTER.
# CENTER has 2 excess bikes.
# Moved 2 bikes from CENTER to UVT.
# Time 1020: Trip from UPT to CENTER
# Time 1020: Customer unhappy. No bikes available at UPT.
# Time 1020: Bike broke down on the trip from UPT to CENTER
# Time 1036: Trip from UPT to CENTER
# Time 1036: Customer unhappy. No bikes available at UPT.
# Time 1053: Trip from UPT to UVT
# Time 1053: Customer unhappy. No bikes available at UPT.
# Time 1066: Trip from UVT to UPT
# Time 1080: Rebalancing bikes...
# UPT has 4 excess bikes.
# Moved 4 bikes from UPT to UVT.
# UVT has 6 excess bikes.
# Moved 4 bikes from UVT to UPT.
# Moved 2 bikes from UVT to CENTER.
# CENTER has 2 excess bikes.
# Moved 2 bikes from CENTER to UVT.
# Time 1080: Trip from UPT to CENTER
# Time 1080: Customer unhappy. No bikes available at UPT.
# Time 1080: Bike broke down on the trip from UPT to CENTER
# Time 1097: Trip from UPT to CENTER
# Time 1097: Customer unhappy. No bikes available at UPT.
# Time 1097: Bike broke down on the trip from UPT to CENTER
# Time 1110: Trip from UVT to CENTER
# Time 1122: Trip from UVT to UPT
# Time 1122: Bike broke down on the trip from UVT to UPT
# Time 1133: Trip from UPT to CENTER
# Time 1133: Customer unhappy. No bikes available at UPT.
# Time 1140: Rebalancing bikes...
# UPT has 4 excess bikes.
# Moved 4 bikes from UPT to UVT.
# UVT has 6 excess bikes.
# Moved 4 bikes from UVT to UPT.
# Moved 2 bikes from UVT to CENTER.
# CENTER has 2 excess bikes.
# Moved 2 bikes from CENTER to UVT.
# Time 1146: Trip from UVT to UPT
# Time 1159: Trip from CENTER to UPT
# Time 1170: Trip from PARK to UPT
# Time 1170: Bike broke down on the trip from PARK to UPT
# Time 1186: Trip from UPT to CENTER
# Time 1186: Customer unhappy. No bikes available at UPT.
# Time 1186: Bike broke down on the trip from UPT to CENTER
# Time 1196: Trip from CENTER to UPT
# Time 1196: Bike broke down on the trip from CENTER to UPT
# Time 1200: Rebalancing bikes...
# UPT has 4 excess bikes.
# Moved 4 bikes from UPT to UVT.
# UVT has 6 excess bikes.
# Moved 4 bikes from UVT to UPT.
# Moved 2 bikes from UVT to CENTER.
# CENTER has 2 excess bikes.
# Moved 2 bikes from CENTER to UVT.
# Time 1214: Trip from UPT to PARK
# Time 1214: Customer unhappy. No bikes available at UPT.
# Time 1230: Trip from UPT to PARK
# Time 1230: Customer unhappy. No bikes available at UPT.
# Time 1248: Trip from PARK to UPT
# Time 1248: Bike broke down on the trip from PARK to UPT
# Time 1260: Rebalancing bikes...
# UPT has 4 excess bikes.
# Moved 4 bikes from UPT to UVT.
# UVT has 6 excess bikes.
# Moved 4 bikes from UVT to UPT.
# Moved 2 bikes from UVT to CENTER.
# CENTER has 2 excess bikes.
# Moved 2 bikes from CENTER to UVT.
# Time 1266: Trip from PARK to UPT
# Time 1286: Trip from UPT to UVT
# Time 1286: Customer unhappy. No bikes available at UPT.
# Time 1286: Bike broke down on the trip from UPT to UVT
# Time 1302: Trip from PARK to UPT
# Time 1315: Trip from PARK to UPT
# Time 1315: Bike broke down on the trip from PARK to UPT
# Time 1320: Rebalancing bikes...
# UPT has 4 excess bikes.
# Moved 4 bikes from UPT to UVT.
# UVT has 6 excess bikes.
# Moved 4 bikes from UVT to UPT.
# Moved 2 bikes from UVT to CENTER.
# CENTER has 2 excess bikes.
# Moved 2 bikes from CENTER to UVT.
# Time 1327: Trip from CENTER to UPT
# Time 1327: Bike broke down on the trip from CENTER to UPT
# Time 1342: Trip from UPT to UVT
# Time 1342: Customer unhappy. No bikes available at UPT.
# Time 1356: Trip from UVT to UPT
# Time 1373: Trip from PARK to UPT
# Time 1380: Rebalancing bikes...
# UPT has 4 excess bikes.
# Moved 4 bikes from UPT to UVT.
# UVT has 6 excess bikes.
# Moved 4 bikes from UVT to UPT.
# Moved 2 bikes from UVT to CENTER.
# CENTER has 2 excess bikes.
# Moved 2 bikes from CENTER to UVT.
# Time 1384: Trip from PARK to UPT
# Time 1396: Trip from UPT to CENTER
# Time 1396: Customer unhappy. No bikes available at UPT.
# Time 1396: Bike broke down on the trip from UPT to CENTER
# Time 1416: Trip from UPT to UVT
# Time 1416: Customer unhappy. No bikes available at UPT.
# Time 1432: Trip from UPT to PARK
# Time 1432: Customer unhappy. No bikes available at UPT.
#
# Final statistics:
# Bike levels at each station:
# UPT: 10
# UVT: 8
# CENTER: 6
# PARK: 0
# Unhappy customers due to unavailable bikes: 36
# Unhappy customers due to full stations: 0
